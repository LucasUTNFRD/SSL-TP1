# %%
from grammar import *

def parser(lista_tokens):  # la lista de tokens viene del lexer
    datos_parser = {
        'tokens': lista_tokens + [('#', '#')],
        'posicion_indice': 0,
        'error': False,
    }

    def principal():
        print(datos_parser['tokens'])
        pni('Program')
        token_actual = datos_parser['tokens'][datos_parser['posicion_indice']][0]
        if token_actual != '#' or datos_parser['error']:
            print('La cadena no pertenece al lenguaje')
            return False
        else:
            print('La cadena pertenece al lenguaje')

    def pni(no_terminal):
        terminal = datos_parser['tokens'][datos_parser['posicion_indice']][0]
        parteDerecha = SD[no_terminal][terminal]  # no terminal es el tope de la pila, terminal es donde apunta el puntero en la cadena
        print(f'Derivando {no_terminal} -> {" ".join(parteDerecha)}')
        procesar(parteDerecha)

    def procesar(cuerpo_produccion):  # ingresa una producción
        for simbolo in cuerpo_produccion:
            token_actual = datos_parser['tokens'][datos_parser['posicion_indice']][0]
            datos_parser['error'] = False
            print(f'Procesando Producción: {simbolo}')
            if simbolo in VT:
                if simbolo == token_actual:
                    datos_parser['posicion_indice'] += 1
                else:
                    datos_parser['error'] = True
                    break

            elif simbolo in VN:
                pni(simbolo)
                if datos_parser['error']:
                    break

    return principal()

# %% [markdown]
# ## Ejemplos
#
# Algunos ejemplos de salidad del parser
#
# ### Ejemplo 1:
#
# ```python
# parser(lexer("si 6>7 entonces leer id finsi"))

# %%
parser(lexer("si 6>7 entonces leer id finsi"))
# Out:
# [('si', 'si'), ('numero', '6'), ('oprel', '>'), ('numero', '7'), ('entonces', 'entonces'), ('leer', 'leer'), ('id', 'id'), ('finsi', 'finsi'), ('#', '#')]
# Derivando Program -> ListaSentencias
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaSi
# Procesando Producción: SentenciaSi
# Derivando SentenciaSi -> si Expresion entonces ListaSentencias SentenciaSi_Prime
# Procesando Producción: si
# Procesando Producción: Expresion
# Derivando Expresion -> Expresion2 Expresion_Prime
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: Expresion_Prime
# Derivando Expresion_Prime -> oprel Expresion2
# Procesando Producción: oprel
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: entonces
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaLeer
# Procesando Producción: SentenciaLeer
# Derivando SentenciaLeer -> leer id
# Procesando Producción: leer
# Procesando Producción: id
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# Procesando Producción: SentenciaSi_Prime
# Derivando SentenciaSi_Prime -> finsi
# Procesando Producción: finsi
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# La cadena pertenece al lenguaje

# %% [markdown]
# ### Ejemplo 2:
#
# ```python
# parser(lexer("si 4 > 3 entonces repetir leer id hasta 3 sino mostrar 4 finsi"))

# %%
parser(lexer("si 4 > 3 entonces repetir leer id hasta 3 sino mostrar 4 finsi"))
# Out:
# [('si', 'si'), ('numero', '4'), ('oprel', '>'), ('numero', '3'), ('entonces', 'entonces'), ('repetir', 'repetir'), ('leer', 'leer'), ('id', 'id'), ('hasta', 'hasta'), ('numero', '3'), ('sino', 'sino'), ('mostrar', 'mostrar'), ('numero', '4'), ('finsi', 'finsi'), ('#', '#')]
# Derivando Program -> ListaSentencias
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaSi
# Procesando Producción: SentenciaSi
# Derivando SentenciaSi -> si Expresion entonces ListaSentencias SentenciaSi_Prime
# Procesando Producción: si
# Procesando Producción: Expresion
# Derivando Expresion -> Expresion2 Expresion_Prime
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: Expresion_Prime
# Derivando Expresion_Prime -> oprel Expresion2
# Procesando Producción: oprel
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: entonces
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaRepetir
# Procesando Producción: SentenciaRepetir
# Derivando SentenciaRepetir -> repetir ListaSentencias hasta Expresion
# Procesando Producción: repetir
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaLeer
# Procesando Producción: SentenciaLeer
# Derivando SentenciaLeer -> leer id
# Procesando Producción: leer
# Procesando Producción: id
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# Procesando Producción: hasta
# Procesando Producción: Expresion
# Derivando Expresion -> Expresion2 Expresion_Prime
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: Expresion_Prime
# Derivando Expresion_Prime ->
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# Procesando Producción: SentenciaSi_Prime
# Derivando SentenciaSi_Prime -> sino ListaSentencias finsi
# Procesando Producción: sino
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaMostrar
# Procesando Producción: SentenciaMostrar
# Derivando SentenciaMostrar -> mostrar Expresion
# Procesando Producción: mostrar
# Procesando Producción: Expresion
# Derivando Expresion -> Expresion2 Expresion_Prime
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: Expresion_Prime
# Derivando Expresion_Prime ->
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# Procesando Producción: finsi
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# La cadena pertenece al lenguaje

# %% [markdown]
# ### Ejemplo 2:
#
# ```python
# parser(lexer('mostrar 3 * 2 > 5 * 6'))

# %%
parser(lexer('mostrar 3 * 2 > 5 * 6'))
# Out:
# [('mostrar', 'mostrar'), ('numero', '3'), ('opmult', '*'), ('numero', '2'), ('oprel', '>'), ('numero', '5'), ('opmult', '*'), ('numero', '6'), ('#', '#')]
# Derivando Program -> ListaSentencias
# Procesando Producción: ListaSentencias
# Derivando ListaSentencias -> Sentencia ListaSentencias_Prime
# Procesando Producción: Sentencia
# Derivando Sentencia -> SentenciaMostrar
# Procesando Producción: SentenciaMostrar
# Derivando SentenciaMostrar -> mostrar Expresion
# Procesando Producción: mostrar
# Procesando Producción: Expresion
# Derivando Expresion -> Expresion2 Expresion_Prime
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime -> opmult Factor Termino_Prime
# Procesando Producción: opmult
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: Expresion_Prime
# Derivando Expresion_Prime -> oprel Expresion2
# Procesando Producción: oprel
# Procesando Producción: Expresion2
# Derivando Expresion2 -> Termino Expresion2_Prime
# Procesando Producción: Termino
# Derivando Termino -> Factor Termino_Prime
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime -> opmult Factor Termino_Prime
# Procesando Producción: opmult
# Procesando Producción: Factor
# Derivando Factor -> numero
# Procesando Producción: numero
# Procesando Producción: Termino_Prime
# Derivando Termino_Prime ->
# Procesando Producción: Expresion2_Prime
# Derivando Expresion2_Prime ->
# Procesando Producción: ListaSentencias_Prime
# Derivando ListaSentencias_Prime ->
# La cadena pertenece al lenguaje
